# %%
import carla
import time
import datetime
import random
import pandas as pd
import matplotlib.pyplot as plt

# Connect to CARLA
client = carla.Client('localhost', 2000)
client.set_timeout(5.0)
world = client.get_world()

# Get map and spawn points
map = world.get_map()
spawn_points = map.get_spawn_points()
start_point = random.choice(spawn_points)

# Spawn the vehicle
vehicle_bp = world.get_blueprint_library().filter('*firetruck*')[0]
vehicle = world.try_spawn_actor(vehicle_bp, start_point)

if not vehicle:
    print("Failed to spawn vehicle.")
    exit()

print(f"Vehicle spawned at {start_point.location}")

# Disable autopilot (We will manually apply noisy waypoints)
vehicle.set_autopilot(False)

# Attach Collision Sensor
collision_bp = world.get_blueprint_library().find('sensor.other.collision')
collision_sensor = world.spawn_actor(collision_bp, carla.Transform(), attach_to=vehicle)

# Set up CSV File for Results
csv_filename = "waypoint_noise_incidents.csv"
data_records = []

# Initial Noise Level
noise_level = 0.3  # Start small (0.3m)
noise_increment = 0.3  # Increase every minute
experiment_duration = 10 * 60  # 10 minutes in seconds
noise_update_interval = 60  # Increase noise every 60 seconds

# Track simulation time
start_time = time.time()
crash_count = 0  # Track number of crashes

# Collision detection function

def collision_callback(event):
    global crash_count
    print("Collision detected!")
    crash_count += 1
    
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    data_records.append({
        "Timestamp": timestamp,
        "Noise_Level": noise_level,
        "Collision": "Yes",
        "Waypoint_X": None,
        "Waypoint_Y": None,
        "Waypoint_Z": None,
        "Noisy_Waypoint_X": None,
        "Noisy_Waypoint_Y": None,
        "Noisy_Waypoint_Z": None
    })
    
    # Reset vehicle to a new random spawn point
    reset_location = random.choice(spawn_points)
    vehicle.set_transform(reset_location)
    print("Vehicle reset after collision. Continuing experiment.")

# Cleanup function
def cleanup():
    print("Cleaning up...")
    df = pd.DataFrame(data_records)
    df.to_csv(csv_filename, index=False)
    print(f"Incident data saved to {csv_filename}")
    print(f"Total crashes recorded: {crash_count}")

    if collision_sensor:
        collision_sensor.destroy()
    if vehicle:
        vehicle.destroy()
    print("Vehicle & sensors destroyed. Exiting program.")

    # Generate Graph
    plot_results(df)

# Noisy Waypoint Function
def noisy_waypoint(original_waypoint, noise):
    noisy_x = original_waypoint.transform.location.x + random.uniform(-noise, noise)
    noisy_y = original_waypoint.transform.location.y + random.uniform(-noise, noise)
    return carla.Transform(carla.Location(x=noisy_x, y=noisy_y, z=original_waypoint.transform.location.z), original_waypoint.transform.rotation)

# Visualization Function
def plot_results(df):
    plt.figure(figsize=(8, 5))
    df_crash = df[df["Collision"] == "Yes"]
    plt.scatter(df_crash["Noise_Level"], df_crash.index, color='red', label='Collisions')
    plt.xlabel("Noise Level (meters)")
    plt.ylabel("Collision Occurrence")
    plt.title("Impact of Noise on Collisions")
    plt.legend()
    plt.grid()
    plt.show()

# Start collision sensor
collision_sensor.listen(collision_callback)

print("Vehicle navigating with noisy waypoints...")

try:
    last_noise_update = start_time
    
    while time.time() - start_time < experiment_duration:
        current_time = time.time()
        
        # Increase noise level every minute
        if current_time - last_noise_update >= noise_update_interval:
            noise_level += noise_increment
            last_noise_update = current_time
            print(f"Noise level increased to {noise_level} meters")
        
        current_location = vehicle.get_location()
        next_waypoint_options = map.get_waypoint(current_location).next(5.0)

        if not next_waypoint_options:
            print("No further waypoints found! Resetting vehicle...")
            vehicle.set_transform(random.choice(spawn_points))
            continue
        
        next_waypoint = next_waypoint_options[0]
        noisy_transform = noisy_waypoint(next_waypoint, noise_level)
        vehicle.set_transform(noisy_transform)

        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data_records.append({
            "Timestamp": timestamp,
            "Noise_Level": noise_level,
            "Collision": "No",
            "Waypoint_X": next_waypoint.transform.location.x,
            "Waypoint_Y": next_waypoint.transform.location.y,
            "Waypoint_Z": next_waypoint.transform.location.z,
            "Noisy_Waypoint_X": noisy_transform.location.x,
            "Noisy_Waypoint_Y": noisy_transform.location.y,
            "Noisy_Waypoint_Z": noisy_transform.location.z
        })

        print(f"Noisy Waypoint Applied: {noisy_transform.location}")
        time.sleep(0.5)

except KeyboardInterrupt:
    print("\nManual stop detected! Cleaning up before exiting...")
    cleanup()

cleanup()
# Out:
# Vehicle spawned at Location(x=-28.726021, y=28.104218, z=0.600000)
# Vehicle navigating with noisy waypoints...
# Noisy Waypoint Applied: Location(x=-23.868914, y=28.371481, z=0.000000)
# Noisy Waypoint Applied: Location(x=-19.083704, y=28.399624, z=0.000000)
# Noisy Waypoint Applied: Location(x=-14.342987, y=27.848156, z=0.000000)
# Noisy Waypoint Applied: Location(x=-9.447424, y=28.043968, z=0.000000)
# Noisy Waypoint Applied: Location(x=-4.655628, y=28.198345, z=0.000000)
# Noisy Waypoint Applied: Location(x=0.094170, y=28.314709, z=0.000000)
# Noisy Waypoint Applied: Location(x=4.855865, y=28.117956, z=0.000000)
# Noisy Waypoint Applied: Location(x=9.804182, y=27.970467, z=0.000000)
# Noisy Waypoint Applied: Location(x=14.585923, y=28.235853, z=0.000000)
# Noisy Waypoint Applied: Location(x=19.675320, y=28.521933, z=0.000000)
# Noisy Waypoint Applied: Location(x=24.944212, y=28.183969, z=0.000000)
# Noisy Waypoint Applied: Location(x=29.463614, y=28.236633, z=0.000000)
# Noisy Waypoint Applied: Location(x=34.691471, y=28.501566, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.724167, y=28.121054, z=0.000000)
# Noisy Waypoint Applied: Location(x=44.943592, y=28.463657, z=0.000000)
# Noisy Waypoint Applied: Location(x=49.738789, y=28.383026, z=0.000000)
# Noisy Waypoint Applied: Location(x=54.806969, y=28.528879, z=0.000000)
# Noisy Waypoint Applied: Location(x=59.974194, y=28.057783, z=0.000000)
# Noisy Waypoint Applied: Location(x=65.266312, y=28.101007, z=0.000000)
# Noisy Waypoint Applied: Location(x=70.091400, y=28.470577, z=0.000000)
# Noisy Waypoint Applied: Location(x=74.794357, y=28.394344, z=0.000000)
# Noisy Waypoint Applied: Location(x=79.554535, y=28.257174, z=0.000000)
# Noisy Waypoint Applied: Location(x=84.712303, y=28.430952, z=0.000000)
# Noisy Waypoint Applied: Location(x=89.373062, y=28.616438, z=0.000000)
# Noisy Waypoint Applied: Location(x=93.762291, y=29.506109, z=0.000000)
# Noisy Waypoint Applied: Location(x=97.511406, y=31.653595, z=0.000000)
# Noisy Waypoint Applied: Location(x=100.426186, y=34.578239, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.405289, y=38.477787, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.794456, y=42.789669, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.436203, y=47.971798, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.399605, y=52.850693, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.221497, y=57.808899, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.664780, y=62.825306, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.119858, y=68.108910, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.284233, y=72.935013, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.308685, y=78.051559, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.586983, y=83.026901, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.053551, y=87.795547, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.005356, y=92.913521, z=0.000000)
# Noisy Waypoint Applied: Location(x=101.945854, y=97.720650, z=0.000000)
# Noisy Waypoint Applied: Location(x=100.912666, y=102.494408, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.861862, y=107.184174, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.153687, y=111.491440, z=0.000000)
# Noisy Waypoint Applied: Location(x=95.492317, y=115.728325, z=0.000000)
# Noisy Waypoint Applied: Location(x=93.076523, y=119.736588, z=0.000000)
# Noisy Waypoint Applied: Location(x=89.842041, y=123.458153, z=0.000000)
# Noisy Waypoint Applied: Location(x=86.416771, y=126.814423, z=0.000000)
# Noisy Waypoint Applied: Location(x=82.324417, y=129.599487, z=0.000000)
# Noisy Waypoint Applied: Location(x=78.112717, y=131.637497, z=0.000000)
# Noisy Waypoint Applied: Location(x=73.619217, y=132.876465, z=0.000000)
# Noisy Waypoint Applied: Location(x=68.820122, y=133.737259, z=0.000000)
# Noisy Waypoint Applied: Location(x=64.221680, y=134.128998, z=0.000000)
# Noisy Waypoint Applied: Location(x=59.173759, y=134.425430, z=0.000000)
# Noisy Waypoint Applied: Location(x=54.308704, y=134.110825, z=0.000000)
# Noisy Waypoint Applied: Location(x=49.401127, y=134.232376, z=0.000000)
# Noisy Waypoint Applied: Location(x=44.431755, y=133.979553, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.473896, y=134.126221, z=0.000000)
# Noisy Waypoint Applied: Location(x=34.606617, y=134.112610, z=0.000000)
# Noisy Waypoint Applied: Location(x=29.815231, y=133.862366, z=0.000000)
# Noisy Waypoint Applied: Location(x=25.077112, y=134.022903, z=0.000000)
# Noisy Waypoint Applied: Location(x=19.988241, y=134.147598, z=0.000000)
# Noisy Waypoint Applied: Location(x=15.260946, y=134.162628, z=0.000000)
# Noisy Waypoint Applied: Location(x=10.565038, y=133.815277, z=0.000000)
# Noisy Waypoint Applied: Location(x=5.399851, y=133.864014, z=0.000000)
# Noisy Waypoint Applied: Location(x=0.630075, y=133.790665, z=0.000000)
# Noisy Waypoint Applied: Location(x=-4.655092, y=133.762695, z=0.000000)
# Noisy Waypoint Applied: Location(x=-9.685755, y=133.885742, z=0.000000)
# Noisy Waypoint Applied: Location(x=-14.390929, y=133.902298, z=0.000000)
# Noisy Waypoint Applied: Location(x=-19.563982, y=133.460541, z=0.000000)
# Noisy Waypoint Applied: Location(x=-24.340858, y=133.488113, z=0.000000)
# Noisy Waypoint Applied: Location(x=-29.351748, y=133.262741, z=0.000000)
# Noisy Waypoint Applied: Location(x=-34.483906, y=133.784531, z=0.000000)
# Noisy Waypoint Applied: Location(x=-39.431404, y=133.693680, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.302994, y=133.388748, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.188091, y=133.404922, z=0.000000)
# Noisy Waypoint Applied: Location(x=-54.448681, y=133.369034, z=0.000000)
# Noisy Waypoint Applied: Location(x=-59.307682, y=133.491776, z=0.000000)
# Noisy Waypoint Applied: Location(x=-64.239784, y=133.031433, z=0.000000)
# Noisy Waypoint Applied: Location(x=-68.576515, y=132.690643, z=0.000000)
# Noisy Waypoint Applied: Location(x=-73.142334, y=131.551346, z=0.000000)
# Noisy Waypoint Applied: Location(x=-77.559959, y=130.056213, z=0.000000)
# Noisy Waypoint Applied: Location(x=-81.796677, y=128.320435, z=0.000000)
# Noisy Waypoint Applied: Location(x=-85.529488, y=125.820267, z=0.000000)
# Noisy Waypoint Applied: Location(x=-89.398285, y=122.684929, z=0.000000)
# Noisy Waypoint Applied: Location(x=-93.065292, y=119.470909, z=0.000000)
# Noisy Waypoint Applied: Location(x=-96.010475, y=115.293839, z=0.000000)
# Noisy Waypoint Applied: Location(x=-98.402367, y=111.303314, z=0.000000)
# Noisy Waypoint Applied: Location(x=-100.783333, y=106.957695, z=0.000000)
# Noisy Waypoint Applied: Location(x=-102.752373, y=102.217827, z=0.000000)
# Noisy Waypoint Applied: Location(x=-104.389282, y=97.530235, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.585907, y=93.177071, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.636635, y=88.232895, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.209457, y=83.391647, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.539528, y=78.723488, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.573662, y=73.700096, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.673759, y=68.727997, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.269539, y=63.983868, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.602493, y=58.777927, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.153534, y=53.517220, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.422379, y=48.367290, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.047592, y=43.415051, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.185478, y=38.644287, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.404655, y=33.350708, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.952316, y=28.227221, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.702927, y=23.400665, z=0.000000)
# Noisy Waypoint Applied: Location(x=-101.924858, y=26.443321, z=0.000000)
# Noisy Waypoint Applied: Location(x=-96.230453, y=28.119520, z=0.000000)
# Noisy Waypoint Applied: Location(x=-91.230721, y=27.786137, z=0.000000)
# Noisy Waypoint Applied: Location(x=-86.190422, y=27.888227, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=99.013298, y=48.960407, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=53.360088, y=-61.080200, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.118431, y=-60.893936, z=0.000000)
# Noisy Waypoint Applied: Location(x=81.982727, y=-56.756073, z=0.000000)
# Noisy Waypoint Applied: Location(x=92.492928, y=-48.894016, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.958733, y=-37.928303, z=0.000000)
# Noisy Waypoint Applied: Location(x=103.011856, y=-25.705740, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.706635, y=-12.880753, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.822769, y=-0.337683, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.549362, y=12.790146, z=0.000000)
# Noise level increased to 0.6 meters
# Noisy Waypoint Applied: Location(x=105.778343, y=16.557135, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.515900, y=26.945345, z=0.000000)
# Noisy Waypoint Applied: Location(x=103.008995, y=36.921551, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.785515, y=46.960594, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.244148, y=57.758240, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.418892, y=68.715508, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.442970, y=79.608810, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.484329, y=90.013870, z=0.000000)
# Noisy Waypoint Applied: Location(x=101.422295, y=99.961922, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.153374, y=110.002975, z=0.000000)
# Noisy Waypoint Applied: Location(x=93.568672, y=119.406731, z=0.000000)
# Noisy Waypoint Applied: Location(x=86.973167, y=126.385841, z=0.000000)
# Noisy Waypoint Applied: Location(x=78.411072, y=131.012039, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.629974, y=133.824402, z=0.000000)
# Noisy Waypoint Applied: Location(x=61.078140, y=134.450043, z=0.000000)
# Noisy Waypoint Applied: Location(x=51.661167, y=133.884613, z=0.000000)
# Noisy Waypoint Applied: Location(x=42.271610, y=134.515671, z=0.000000)
# Noisy Waypoint Applied: Location(x=33.096447, y=134.004547, z=0.000000)
# Noisy Waypoint Applied: Location(x=23.619070, y=133.858780, z=0.000000)
# Noisy Waypoint Applied: Location(x=14.085546, y=133.694458, z=0.000000)
# Noisy Waypoint Applied: Location(x=4.552225, y=133.621063, z=0.000000)
# Noisy Waypoint Applied: Location(x=-5.661776, y=133.344131, z=0.000000)
# Noisy Waypoint Applied: Location(x=-15.852302, y=133.134308, z=0.000000)
# Noisy Waypoint Applied: Location(x=-26.123455, y=133.981552, z=0.000000)
# Noisy Waypoint Applied: Location(x=-35.841103, y=133.780624, z=0.000000)
# Noisy Waypoint Applied: Location(x=-45.211517, y=132.948257, z=0.000000)
# Noisy Waypoint Applied: Location(x=-55.000755, y=133.729309, z=0.000000)
# Noisy Waypoint Applied: Location(x=-64.359146, y=133.332504, z=0.000000)
# Noisy Waypoint Applied: Location(x=-73.938980, y=131.721603, z=0.000000)
# Noisy Waypoint Applied: Location(x=-81.790077, y=127.466957, z=0.000000)
# Noisy Waypoint Applied: Location(x=-89.535622, y=123.055489, z=0.000000)
# Noisy Waypoint Applied: Location(x=-95.400856, y=116.043327, z=0.000000)
# Noisy Waypoint Applied: Location(x=-99.467049, y=108.330292, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.445992, y=100.638512, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.143288, y=92.300995, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.541351, y=84.417267, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.183319, y=75.566681, z=0.000000)
# Noisy Waypoint Applied: Location(x=-108.024307, y=66.300095, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.605499, y=57.715889, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-85.307800, y=16.461439, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=99.612312, y=-1.844050, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-48.635818, y=92.020241, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.985737, y=99.863091, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.908344, y=107.029388, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.656399, y=114.031067, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.984932, y=120.478249, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.574436, y=127.079407, z=0.000000)
# Noisy Waypoint Applied: Location(x=-57.346203, y=131.112488, z=0.000000)
# Noisy Waypoint Applied: Location(x=-63.340755, y=133.721909, z=0.000000)
# Noisy Waypoint Applied: Location(x=-70.434669, y=132.337738, z=0.000000)
# Noisy Waypoint Applied: Location(x=-77.114502, y=130.366776, z=0.000000)
# Noisy Waypoint Applied: Location(x=-83.191765, y=127.287926, z=0.000000)
# Noisy Waypoint Applied: Location(x=-89.103378, y=123.196091, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=57.589664, y=69.926422, z=0.000000)
# Noisy Waypoint Applied: Location(x=61.125526, y=69.902435, z=0.000000)
# Noisy Waypoint Applied: Location(x=64.303909, y=69.333031, z=0.000000)
# Noisy Waypoint Applied: Location(x=67.994942, y=69.660431, z=0.000000)
# Noisy Waypoint Applied: Location(x=71.459335, y=69.465637, z=0.000000)
# Noisy Waypoint Applied: Location(x=75.764183, y=69.631401, z=0.000000)
# Noisy Waypoint Applied: Location(x=79.321808, y=70.326378, z=0.000000)
# Noisy Waypoint Applied: Location(x=83.364334, y=70.283272, z=0.000000)
# Noisy Waypoint Applied: Location(x=86.760559, y=70.043343, z=0.000000)
# Noisy Waypoint Applied: Location(x=90.402283, y=69.940193, z=0.000000)
# Noisy Waypoint Applied: Location(x=93.277199, y=70.094315, z=0.000000)
# Noisy Waypoint Applied: Location(x=95.697678, y=71.308258, z=0.000000)
# Noisy Waypoint Applied: Location(x=97.559395, y=73.604393, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.330696, y=76.291458, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.379639, y=79.180458, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.978378, y=83.130600, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.074219, y=86.845566, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.011154, y=91.153114, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.406494, y=94.645744, z=0.000000)
# Noisy Waypoint Applied: Location(x=97.831833, y=98.369247, z=0.000000)
# Noisy Waypoint Applied: Location(x=97.297752, y=102.112755, z=0.000000)
# Noisy Waypoint Applied: Location(x=96.789040, y=105.340660, z=0.000000)
# Noisy Waypoint Applied: Location(x=95.511826, y=108.071060, z=0.000000)
# Noisy Waypoint Applied: Location(x=94.687164, y=111.062592, z=0.000000)
# Noisy Waypoint Applied: Location(x=92.769806, y=114.325867, z=0.000000)
# Noisy Waypoint Applied: Location(x=90.487732, y=116.450546, z=0.000000)
# Noisy Waypoint Applied: Location(x=88.421692, y=120.015045, z=0.000000)
# Noisy Waypoint Applied: Location(x=86.630447, y=122.457367, z=0.000000)
# Noisy Waypoint Applied: Location(x=84.178223, y=124.461601, z=0.000000)
# Noisy Waypoint Applied: Location(x=80.846367, y=126.572884, z=0.000000)
# Noisy Waypoint Applied: Location(x=77.823174, y=127.969566, z=0.000000)
# Noisy Waypoint Applied: Location(x=75.103798, y=129.084061, z=0.000000)
# Noisy Waypoint Applied: Location(x=71.709816, y=129.568756, z=0.000000)
# Noisy Waypoint Applied: Location(x=68.692802, y=131.059021, z=0.000000)
# Noisy Waypoint Applied: Location(x=65.124695, y=130.372726, z=0.000000)
# Noisy Waypoint Applied: Location(x=61.482819, y=130.520767, z=0.000000)
# Noisy Waypoint Applied: Location(x=57.280411, y=131.088654, z=0.000000)
# Noisy Waypoint Applied: Location(x=53.399052, y=131.236038, z=0.000000)
# Noisy Waypoint Applied: Location(x=48.746593, y=130.339310, z=0.000000)
# Noisy Waypoint Applied: Location(x=44.377205, y=130.574066, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.921600, y=130.197739, z=0.000000)
# Noisy Waypoint Applied: Location(x=35.789082, y=130.520554, z=0.000000)
# Noisy Waypoint Applied: Location(x=32.328415, y=130.600479, z=0.000000)
# Noisy Waypoint Applied: Location(x=28.047106, y=130.518372, z=0.000000)
# Noisy Waypoint Applied: Location(x=23.716379, y=130.537292, z=0.000000)
# Noisy Waypoint Applied: Location(x=19.806997, y=130.383347, z=0.000000)
# Noisy Waypoint Applied: Location(x=15.681883, y=130.031784, z=0.000000)
# Noisy Waypoint Applied: Location(x=11.684590, y=130.590561, z=0.000000)
# Noisy Waypoint Applied: Location(x=7.751466, y=130.055817, z=0.000000)
# Noisy Waypoint Applied: Location(x=3.284281, y=130.213226, z=0.000000)
# Noisy Waypoint Applied: Location(x=-1.057157, y=129.614380, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=102.219063, y=85.127930, z=0.000000)
# Noisy Waypoint Applied: Location(x=101.797203, y=89.781090, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.248184, y=95.336807, z=0.000000)
# Noisy Waypoint Applied: Location(x=101.323143, y=100.254791, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.977379, y=105.063011, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.205566, y=109.667870, z=0.000000)
# Noisy Waypoint Applied: Location(x=96.429749, y=113.894287, z=0.000000)
# Noisy Waypoint Applied: Location(x=94.305611, y=118.703293, z=0.000000)
# Noisy Waypoint Applied: Location(x=90.572289, y=122.230850, z=0.000000)
# Noisy Waypoint Applied: Location(x=87.045334, y=125.993614, z=0.000000)
# Noisy Waypoint Applied: Location(x=83.212387, y=128.905075, z=0.000000)
# Noisy Waypoint Applied: Location(x=79.163063, y=131.679535, z=0.000000)
# Noisy Waypoint Applied: Location(x=74.584160, y=132.730759, z=0.000000)
# Noisy Waypoint Applied: Location(x=70.365929, y=134.157043, z=0.000000)
# Noise level increased to 0.8999999999999999 meters
# Noisy Waypoint Applied: Location(x=64.967575, y=134.198547, z=0.000000)
# Noisy Waypoint Applied: Location(x=60.414040, y=133.858109, z=0.000000)
# Noisy Waypoint Applied: Location(x=54.805405, y=133.548798, z=0.000000)
# Noisy Waypoint Applied: Location(x=49.983608, y=134.921310, z=0.000000)
# Noisy Waypoint Applied: Location(x=44.892471, y=133.537201, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.321754, y=133.953552, z=0.000000)
# Noisy Waypoint Applied: Location(x=34.046967, y=133.367706, z=0.000000)
# Noisy Waypoint Applied: Location(x=28.448883, y=134.842392, z=0.000000)
# Noisy Waypoint Applied: Location(x=23.459492, y=134.290924, z=0.000000)
# Noisy Waypoint Applied: Location(x=17.722881, y=134.514648, z=0.000000)
# Noisy Waypoint Applied: Location(x=13.299855, y=133.693436, z=0.000000)
# Noisy Waypoint Applied: Location(x=7.719287, y=134.637863, z=0.000000)
# Noisy Waypoint Applied: Location(x=2.159368, y=133.280914, z=0.000000)
# Noisy Waypoint Applied: Location(x=-2.857911, y=133.076981, z=0.000000)
# Noisy Waypoint Applied: Location(x=-8.814370, y=132.805511, z=0.000000)
# Noisy Waypoint Applied: Location(x=-14.450171, y=133.924774, z=0.000000)
# Noisy Waypoint Applied: Location(x=-20.406601, y=133.665329, z=0.000000)
# Noisy Waypoint Applied: Location(x=-25.908354, y=133.133575, z=0.000000)
# Noisy Waypoint Applied: Location(x=-30.931145, y=133.681610, z=0.000000)
# Noisy Waypoint Applied: Location(x=-35.484146, y=133.545929, z=0.000000)
# Noisy Waypoint Applied: Location(x=-39.922764, y=132.749786, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.380535, y=132.761002, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.800274, y=133.716812, z=0.000000)
# Noisy Waypoint Applied: Location(x=-54.595409, y=133.161438, z=0.000000)
# Noisy Waypoint Applied: Location(x=-59.021160, y=132.982605, z=0.000000)
# Noisy Waypoint Applied: Location(x=-64.261757, y=132.442978, z=0.000000)
# Noisy Waypoint Applied: Location(x=-68.832344, y=131.934677, z=0.000000)
# Noisy Waypoint Applied: Location(x=-73.115036, y=131.917740, z=0.000000)
# Noisy Waypoint Applied: Location(x=-77.362762, y=130.961884, z=0.000000)
# Noisy Waypoint Applied: Location(x=-81.856209, y=127.728386, z=0.000000)
# Noisy Waypoint Applied: Location(x=-86.871475, y=125.665329, z=0.000000)
# Noisy Waypoint Applied: Location(x=-91.028526, y=122.957664, z=0.000000)
# Noisy Waypoint Applied: Location(x=-93.012634, y=118.151115, z=0.000000)
# Noisy Waypoint Applied: Location(x=-95.818367, y=115.302979, z=0.000000)
# Noisy Waypoint Applied: Location(x=-98.266472, y=111.594460, z=0.000000)
# Noisy Waypoint Applied: Location(x=-100.881874, y=108.086617, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.035751, y=103.879608, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.347816, y=99.340546, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.928513, y=95.845383, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.177101, y=91.344475, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.888466, y=86.242111, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.630791, y=80.882286, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.834511, y=76.845940, z=0.000000)
# Noisy Waypoint Applied: Location(x=-108.326935, y=71.395409, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.694603, y=66.294846, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.901161, y=62.129837, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.567017, y=57.752071, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.537109, y=53.493176, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.221191, y=48.405529, z=0.000000)
# Noisy Waypoint Applied: Location(x=-108.115448, y=44.040672, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.438385, y=40.145172, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.855103, y=34.676205, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.256241, y=29.558666, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.929054, y=24.973026, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.788094, y=19.463388, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.387543, y=14.365270, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.519180, y=9.077766, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.920052, y=3.564934, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.056976, y=-1.084661, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.826874, y=-5.874283, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.895905, y=-10.522334, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.733002, y=-15.888360, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.003632, y=-20.817659, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.149818, y=-26.313375, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.402130, y=-30.027485, z=0.000000)
# Noisy Waypoint Applied: Location(x=-104.972717, y=-34.790108, z=0.000000)
# Noisy Waypoint Applied: Location(x=-102.241791, y=-39.456852, z=0.000000)
# Noisy Waypoint Applied: Location(x=-99.680473, y=-43.990906, z=0.000000)
# Noisy Waypoint Applied: Location(x=-98.437965, y=-47.267555, z=0.000000)
# Noisy Waypoint Applied: Location(x=-95.228775, y=-50.262718, z=0.000000)
# Noisy Waypoint Applied: Location(x=-92.698120, y=-53.312485, z=0.000000)
# Noisy Waypoint Applied: Location(x=-88.912544, y=-56.821053, z=0.000000)
# Noisy Waypoint Applied: Location(x=-83.970207, y=-58.226566, z=0.000000)
# Noisy Waypoint Applied: Location(x=-79.411377, y=-59.888073, z=0.000000)
# Noisy Waypoint Applied: Location(x=-75.387505, y=-61.258434, z=0.000000)
# Noisy Waypoint Applied: Location(x=-71.418243, y=-62.342072, z=0.000000)
# Noisy Waypoint Applied: Location(x=-66.516975, y=-61.926487, z=0.000000)
# Noisy Waypoint Applied: Location(x=-61.183147, y=-61.956001, z=0.000000)
# Noisy Waypoint Applied: Location(x=-56.212780, y=-61.748627, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.967628, y=-61.306862, z=0.000000)
# Noisy Waypoint Applied: Location(x=-56.073242, y=-64.679855, z=0.000000)
# Noisy Waypoint Applied: Location(x=-61.788811, y=-64.451599, z=0.000000)
# Noisy Waypoint Applied: Location(x=-66.079674, y=-65.319801, z=0.000000)
# Noisy Waypoint Applied: Location(x=-71.720497, y=-65.802269, z=0.000000)
# Noisy Waypoint Applied: Location(x=-77.600662, y=-64.104149, z=0.000000)
# Noisy Waypoint Applied: Location(x=-82.657768, y=-63.997837, z=0.000000)
# Noisy Waypoint Applied: Location(x=-87.920616, y=-60.453144, z=0.000000)
# Noisy Waypoint Applied: Location(x=-93.050919, y=-57.956524, z=0.000000)
# Noisy Waypoint Applied: Location(x=-96.858765, y=-53.567028, z=0.000000)
# Noisy Waypoint Applied: Location(x=-101.192001, y=-50.139599, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.312019, y=-45.954300, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.273308, y=-41.810730, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.464775, y=-36.705830, z=0.000000)
# Noisy Waypoint Applied: Location(x=-108.060036, y=-31.645748, z=0.000000)
# Noisy Waypoint Applied: Location(x=-109.011063, y=-27.417963, z=0.000000)
# Noisy Waypoint Applied: Location(x=-109.747147, y=-21.752054, z=0.000000)
# Noisy Waypoint Applied: Location(x=-109.616211, y=-16.393476, z=0.000000)
# Noisy Waypoint Applied: Location(x=-109.300392, y=-12.113104, z=0.000000)
# Noisy Waypoint Applied: Location(x=-109.564720, y=-6.591849, z=0.000000)
# Noisy Waypoint Applied: Location(x=-111.076584, y=-1.458648, z=0.000000)
# Noisy Waypoint Applied: Location(x=-110.791832, y=3.115353, z=0.000000)
# Noisy Waypoint Applied: Location(x=-110.208672, y=7.372318, z=0.000000)
# Noisy Waypoint Applied: Location(x=-108.845238, y=12.712790, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.465561, y=17.196707, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.669044, y=12.835603, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.070518, y=8.453496, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.130020, y=4.346150, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.247368, y=0.186901, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.218002, y=-4.198605, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.103668, y=-9.701302, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.353561, y=-15.445451, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.612396, y=-20.663553, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.773407, y=-24.978968, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.036644, y=-29.506025, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.542465, y=-33.615822, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.493988, y=-38.096809, z=0.000000)
# Noisy Waypoint Applied: Location(x=-100.725685, y=-41.792004, z=0.000000)
# Noisy Waypoint Applied: Location(x=-99.258217, y=-46.392708, z=0.000000)
# Noisy Waypoint Applied: Location(x=-95.414078, y=-50.845161, z=0.000000)
# Noise level increased to 1.2 meters
# Noisy Waypoint Applied: Location(x=-92.873360, y=-52.908730, z=0.000000)
# Noisy Waypoint Applied: Location(x=-90.597954, y=-54.994026, z=0.000000)
# Noisy Waypoint Applied: Location(x=-87.794456, y=-56.691467, z=0.000000)
# Noisy Waypoint Applied: Location(x=-83.854156, y=-58.137169, z=0.000000)
# Noisy Waypoint Applied: Location(x=-78.683784, y=-61.120815, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=19.747334, y=134.700867, z=0.000000)
# Noisy Waypoint Applied: Location(x=-1.752478, y=133.568649, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=0.451412, y=27.960405, z=0.000000)
# Noisy Waypoint Applied: Location(x=-6.521414, y=28.412243, z=0.000000)
# Noisy Waypoint Applied: Location(x=-14.296169, y=28.683517, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=98.996017, y=47.316811, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.527046, y=51.743530, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.499756, y=56.157387, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.577477, y=61.321915, z=0.000000)
# Noisy Waypoint Applied: Location(x=100.017113, y=67.242104, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.551193, y=72.874161, z=0.000000)
# Noisy Waypoint Applied: Location(x=97.873703, y=77.800026, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.162148, y=83.217628, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.946815, y=89.596260, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.517372, y=93.520576, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.190033, y=98.192657, z=0.000000)
# Noisy Waypoint Applied: Location(x=96.309593, y=102.225372, z=0.000000)
# Noisy Waypoint Applied: Location(x=94.921379, y=105.972435, z=0.000000)
# Noisy Waypoint Applied: Location(x=95.428421, y=111.377525, z=0.000000)
# Noisy Waypoint Applied: Location(x=91.950523, y=114.818993, z=0.000000)
# Noisy Waypoint Applied: Location(x=89.782021, y=118.572929, z=0.000000)
# Noisy Waypoint Applied: Location(x=87.663460, y=121.938713, z=0.000000)
# Noisy Waypoint Applied: Location(x=83.052315, y=124.438347, z=0.000000)
# Noisy Waypoint Applied: Location(x=80.223763, y=125.964638, z=0.000000)
# Noisy Waypoint Applied: Location(x=75.409500, y=128.999649, z=0.000000)
# Noisy Waypoint Applied: Location(x=70.327812, y=129.185562, z=0.000000)
# Noisy Waypoint Applied: Location(x=65.356407, y=131.734650, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=20.177202, y=66.803421, z=0.000000)
# Noisy Waypoint Applied: Location(x=14.802560, y=65.899635, z=0.000000)
# Noisy Waypoint Applied: Location(x=7.625786, y=65.725655, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-114.196495, y=48.503563, z=0.000000)
# Noisy Waypoint Applied: Location(x=-115.549431, y=55.175842, z=0.000000)
# Noisy Waypoint Applied: Location(x=-113.683823, y=61.288368, z=0.000000)
# Noisy Waypoint Applied: Location(x=-115.271484, y=67.708817, z=0.000000)
# Noisy Waypoint Applied: Location(x=-114.387840, y=75.227280, z=0.000000)
# Noisy Waypoint Applied: Location(x=-115.469467, y=82.694687, z=0.000000)
# Noisy Waypoint Applied: Location(x=-113.360504, y=89.958611, z=0.000000)
# Noisy Waypoint Applied: Location(x=-111.213814, y=97.172157, z=0.000000)
# Noisy Waypoint Applied: Location(x=-110.574570, y=104.922470, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.002129, y=111.899162, z=0.000000)
# Noisy Waypoint Applied: Location(x=-102.569321, y=119.128960, z=0.000000)
# Noisy Waypoint Applied: Location(x=-96.555038, y=123.648254, z=0.000000)
# Noisy Waypoint Applied: Location(x=-92.031197, y=128.788208, z=0.000000)
# Noisy Waypoint Applied: Location(x=-85.782631, y=134.807373, z=0.000000)
# Noisy Waypoint Applied: Location(x=-79.598831, y=138.363647, z=0.000000)
# Noisy Waypoint Applied: Location(x=-72.795517, y=139.386703, z=0.000000)
# Noisy Waypoint Applied: Location(x=-66.170357, y=140.255478, z=0.000000)
# Noisy Waypoint Applied: Location(x=-59.825188, y=140.933044, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.661125, y=140.274078, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.582012, y=139.358887, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.048088, y=141.301163, z=0.000000)
# Noisy Waypoint Applied: Location(x=-32.587490, y=140.664001, z=0.000000)
# Noisy Waypoint Applied: Location(x=-26.073614, y=140.276199, z=0.000000)
# Noisy Waypoint Applied: Location(x=-20.539459, y=140.311691, z=0.000000)
# Noisy Waypoint Applied: Location(x=-12.856886, y=141.195129, z=0.000000)
# Noisy Waypoint Applied: Location(x=-5.552519, y=139.824081, z=0.000000)
# Noisy Waypoint Applied: Location(x=0.523642, y=141.708923, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=26.346807, y=16.830681, z=0.000000)
# Noisy Waypoint Applied: Location(x=23.603722, y=17.679323, z=0.000000)
# Noisy Waypoint Applied: Location(x=20.622099, y=16.172220, z=0.000000)
# Noisy Waypoint Applied: Location(x=16.136721, y=17.863358, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=1.225291, y=28.545103, z=0.000000)
# Noisy Waypoint Applied: Location(x=8.405445, y=27.049011, z=0.000000)
# Noisy Waypoint Applied: Location(x=14.536789, y=27.162086, z=0.000000)
# Noisy Waypoint Applied: Location(x=21.563669, y=28.462444, z=0.000000)
# Noisy Waypoint Applied: Location(x=27.428003, y=28.759714, z=0.000000)
# Noisy Waypoint Applied: Location(x=33.723900, y=30.190353, z=0.000000)
# Noisy Waypoint Applied: Location(x=38.468239, y=33.599815, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.848774, y=37.635471, z=0.000000)
# Noisy Waypoint Applied: Location(x=40.360779, y=43.908653, z=0.000000)
# Noisy Waypoint Applied: Location(x=41.393978, y=50.567039, z=0.000000)
# Noisy Waypoint Applied: Location(x=41.305565, y=57.218483, z=0.000000)
# Noisy Waypoint Applied: Location(x=43.130806, y=64.483749, z=0.000000)
# Noisy Waypoint Applied: Location(x=46.733932, y=68.433296, z=0.000000)
# Noisy Waypoint Applied: Location(x=53.405399, y=70.830017, z=0.000000)
# Noisy Waypoint Applied: Location(x=59.872108, y=68.902138, z=0.000000)
# Noisy Waypoint Applied: Location(x=64.999527, y=69.328636, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.616936, y=69.523926, z=0.000000)
# Noisy Waypoint Applied: Location(x=75.045937, y=69.474297, z=0.000000)
# Noisy Waypoint Applied: Location(x=79.698959, y=70.659813, z=0.000000)
# Noisy Waypoint Applied: Location(x=85.609741, y=70.561676, z=0.000000)
# Noisy Waypoint Applied: Location(x=90.545090, y=71.028130, z=0.000000)
# Noisy Waypoint Applied: Location(x=95.107452, y=72.228394, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.205986, y=76.226662, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.206635, y=80.722855, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.828789, y=85.820206, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.788094, y=91.901077, z=0.000000)
# Noisy Waypoint Applied: Location(x=97.996956, y=96.745987, z=0.000000)
# Noisy Waypoint Applied: Location(x=98.260300, y=101.949646, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-52.198608, y=82.976906, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.733734, y=105.180336, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.963428, y=128.055161, z=0.000000)
# Noisy Waypoint Applied: Location(x=-57.140240, y=140.257462, z=0.000000)
# Noisy Waypoint Applied: Location(x=-60.580685, y=141.339279, z=0.000000)
# Noisy Waypoint Applied: Location(x=-65.075706, y=139.368744, z=0.000000)
# Noisy Waypoint Applied: Location(x=-68.096481, y=138.892746, z=0.000000)
# Noisy Waypoint Applied: Location(x=-70.020126, y=138.406860, z=0.000000)
# Noisy Waypoint Applied: Location(x=-73.692299, y=139.453247, z=0.000000)
# Noisy Waypoint Applied: Location(x=-75.375465, y=138.786743, z=0.000000)
# Noisy Waypoint Applied: Location(x=-77.898994, y=137.515045, z=0.000000)
# Noisy Waypoint Applied: Location(x=-80.631958, y=135.919586, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=29.928707, y=-57.545567, z=0.000000)
# Noisy Waypoint Applied: Location(x=32.177418, y=-58.476425, z=0.000000)
# Noisy Waypoint Applied: Location(x=35.225384, y=-58.506462, z=0.000000)
# Noisy Waypoint Applied: Location(x=36.427364, y=-58.595093, z=0.000000)
# Noisy Waypoint Applied: Location(x=38.501450, y=-57.204655, z=0.000000)
# Noisy Waypoint Applied: Location(x=40.649063, y=-57.532955, z=0.000000)
# Noisy Waypoint Applied: Location(x=42.328186, y=-57.502838, z=0.000000)
# Noisy Waypoint Applied: Location(x=45.328808, y=-58.447472, z=0.000000)
# Noisy Waypoint Applied: Location(x=45.974300, y=-57.179653, z=0.000000)
# Noisy Waypoint Applied: Location(x=48.965008, y=-57.962814, z=0.000000)
# Noisy Waypoint Applied: Location(x=50.801529, y=-58.082172, z=0.000000)
# Noisy Waypoint Applied: Location(x=53.619827, y=-56.531193, z=0.000000)
# Noisy Waypoint Applied: Location(x=56.138844, y=-57.964268, z=0.000000)
# Noise level increased to 1.5 meters
# Noisy Waypoint Applied: Location(x=57.439648, y=-58.300739, z=0.000000)
# Noisy Waypoint Applied: Location(x=58.765739, y=-56.296715, z=0.000000)
# Noisy Waypoint Applied: Location(x=61.077721, y=-56.043186, z=0.000000)
# Noisy Waypoint Applied: Location(x=62.900974, y=-58.257793, z=0.000000)
# Noisy Waypoint Applied: Location(x=66.275810, y=-57.585606, z=0.000000)
# Noisy Waypoint Applied: Location(x=68.197617, y=-58.137997, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.999680, y=-56.933697, z=0.000000)
# Noisy Waypoint Applied: Location(x=70.306870, y=-57.844761, z=0.000000)
# Noisy Waypoint Applied: Location(x=72.028748, y=-57.888699, z=0.000000)
# Noisy Waypoint Applied: Location(x=72.876709, y=-57.222305, z=0.000000)
# Noisy Waypoint Applied: Location(x=73.205315, y=-57.337803, z=0.000000)
# Noisy Waypoint Applied: Location(x=74.298607, y=-56.350750, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-113.535904, y=74.417290, z=0.000000)
# Noisy Waypoint Applied: Location(x=-115.444374, y=80.829361, z=0.000000)
# Noisy Waypoint Applied: Location(x=-114.303032, y=87.597237, z=0.000000)
# Noisy Waypoint Applied: Location(x=-111.555267, y=95.739937, z=0.000000)
# Noisy Waypoint Applied: Location(x=-110.210960, y=102.084419, z=0.000000)
# Noisy Waypoint Applied: Location(x=-108.371277, y=109.659081, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.649399, y=116.676529, z=0.000000)
# Noisy Waypoint Applied: Location(x=-97.508171, y=122.282997, z=0.000000)
# Noisy Waypoint Applied: Location(x=-93.355522, y=130.467438, z=0.000000)
# Noisy Waypoint Applied: Location(x=-85.471352, y=132.894135, z=0.000000)
# Noisy Waypoint Applied: Location(x=-78.879143, y=138.741180, z=0.000000)
# Noisy Waypoint Applied: Location(x=-71.011963, y=140.277252, z=0.000000)
# Noisy Waypoint Applied: Location(x=-62.922291, y=140.995712, z=0.000000)
# Noisy Waypoint Applied: Location(x=-56.410866, y=140.856003, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.022671, y=141.401962, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.399887, y=140.544525, z=0.000000)
# Noisy Waypoint Applied: Location(x=-32.849525, y=140.611984, z=0.000000)
# Noisy Waypoint Applied: Location(x=-24.615181, y=141.151138, z=0.000000)
# Noisy Waypoint Applied: Location(x=-18.448250, y=142.091278, z=0.000000)
# Noisy Waypoint Applied: Location(x=-11.133046, y=140.087128, z=0.000000)
# Noisy Waypoint Applied: Location(x=-2.692404, y=140.756088, z=0.000000)
# Noisy Waypoint Applied: Location(x=4.470820, y=141.355133, z=0.000000)
# Noisy Waypoint Applied: Location(x=10.104143, y=142.149399, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-52.247120, y=-25.658024, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.958721, y=-18.481030, z=0.000000)
# Noisy Waypoint Applied: Location(x=-53.077847, y=-12.783072, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.774815, y=-6.354616, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.123032, y=0.878232, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.504581, y=6.699426, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.189713, y=12.580375, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.956139, y=17.857716, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.812851, y=25.035967, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.508812, y=29.146622, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.814735, y=24.986517, z=0.000000)
# Noisy Waypoint Applied: Location(x=-43.756641, y=19.173182, z=0.000000)
# Noisy Waypoint Applied: Location(x=-38.469975, y=23.692549, z=0.000000)
# Noisy Waypoint Applied: Location(x=-33.389328, y=24.069471, z=0.000000)
# Noisy Waypoint Applied: Location(x=-28.752232, y=23.794996, z=0.000000)
# Noisy Waypoint Applied: Location(x=-24.015835, y=24.606939, z=0.000000)
# Noisy Waypoint Applied: Location(x=-18.127838, y=23.698872, z=0.000000)
# Noisy Waypoint Applied: Location(x=-12.322205, y=24.365374, z=0.000000)
# Noisy Waypoint Applied: Location(x=-5.920185, y=23.382965, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=105.732063, y=-18.248743, z=0.000000)
# Noisy Waypoint Applied: Location(x=106.743156, y=-22.408993, z=0.000000)
# Noisy Waypoint Applied: Location(x=107.729355, y=-27.896763, z=0.000000)
# Noisy Waypoint Applied: Location(x=106.520164, y=-33.634758, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.881927, y=-37.359306, z=0.000000)
# Noisy Waypoint Applied: Location(x=101.617996, y=-41.323242, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.945351, y=-44.953098, z=0.000000)
# Noisy Waypoint Applied: Location(x=95.776505, y=-48.634239, z=0.000000)
# Noisy Waypoint Applied: Location(x=94.755089, y=-52.619137, z=0.000000)
# Noisy Waypoint Applied: Location(x=91.375290, y=-57.149406, z=0.000000)
# Noisy Waypoint Applied: Location(x=87.528053, y=-59.248066, z=0.000000)
# Noisy Waypoint Applied: Location(x=83.549576, y=-62.220325, z=0.000000)
# Noisy Waypoint Applied: Location(x=79.140121, y=-64.649254, z=0.000000)
# Noisy Waypoint Applied: Location(x=75.055313, y=-66.102028, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.475784, y=-66.673744, z=0.000000)
# Noisy Waypoint Applied: Location(x=62.904083, y=-66.611984, z=0.000000)
# Noisy Waypoint Applied: Location(x=57.116020, y=-68.953270, z=0.000000)
# Noisy Waypoint Applied: Location(x=52.005005, y=-67.440491, z=0.000000)
# Noisy Waypoint Applied: Location(x=46.362965, y=-69.414627, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-19.235800, y=134.956161, z=0.000000)
# Noisy Waypoint Applied: Location(x=-21.782364, y=132.288010, z=0.000000)
# Noisy Waypoint Applied: Location(x=-24.766748, y=134.009796, z=0.000000)
# Noisy Waypoint Applied: Location(x=-27.277544, y=133.668304, z=0.000000)
# Noisy Waypoint Applied: Location(x=-29.812597, y=132.595627, z=0.000000)
# Noisy Waypoint Applied: Location(x=-31.822956, y=133.720428, z=0.000000)
# Noisy Waypoint Applied: Location(x=-35.230869, y=134.285950, z=0.000000)
# Noisy Waypoint Applied: Location(x=-38.509613, y=132.879669, z=0.000000)
# Noisy Waypoint Applied: Location(x=-42.642658, y=133.447495, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.558475, y=132.364365, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.588345, y=133.008682, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.580379, y=132.806717, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.951633, y=133.550003, z=0.000000)
# Noisy Waypoint Applied: Location(x=-56.903805, y=133.614136, z=0.000000)
# Noisy Waypoint Applied: Location(x=-58.963364, y=134.220764, z=0.000000)
# Noisy Waypoint Applied: Location(x=-63.191689, y=132.287170, z=0.000000)
# Noisy Waypoint Applied: Location(x=-67.010628, y=131.815247, z=0.000000)
# Noisy Waypoint Applied: Location(x=-69.212494, y=133.804352, z=0.000000)
# Noisy Waypoint Applied: Location(x=-71.861198, y=132.395081, z=0.000000)
# Noisy Waypoint Applied: Location(x=-75.140739, y=132.681366, z=0.000000)
# Noisy Waypoint Applied: Location(x=-79.038643, y=131.136047, z=0.000000)
# Noisy Waypoint Applied: Location(x=-80.364960, y=128.651535, z=0.000000)
# Noisy Waypoint Applied: Location(x=-82.177071, y=128.783447, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=78.953117, y=12.619909, z=0.000000)
# Noisy Waypoint Applied: Location(x=75.858704, y=14.265762, z=0.000000)
# Noisy Waypoint Applied: Location(x=73.209976, y=14.257026, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.753540, y=12.798166, z=0.000000)
# Noisy Waypoint Applied: Location(x=65.568810, y=13.147629, z=0.000000)
# Noisy Waypoint Applied: Location(x=62.978504, y=12.546167, z=0.000000)
# Noisy Waypoint Applied: Location(x=60.307396, y=12.717050, z=0.000000)
# Noisy Waypoint Applied: Location(x=57.614925, y=12.019071, z=0.000000)
# Noisy Waypoint Applied: Location(x=54.338913, y=14.730576, z=0.000000)
# Noisy Waypoint Applied: Location(x=49.544891, y=12.411333, z=0.000000)
# Noisy Waypoint Applied: Location(x=47.491302, y=13.440210, z=0.000000)
# Noisy Waypoint Applied: Location(x=43.317642, y=14.299122, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.204281, y=13.557882, z=0.000000)
# Noisy Waypoint Applied: Location(x=34.342648, y=13.232045, z=0.000000)
# Noisy Waypoint Applied: Location(x=31.609661, y=12.803948, z=0.000000)
# Noisy Waypoint Applied: Location(x=29.503405, y=13.009910, z=0.000000)
# Noisy Waypoint Applied: Location(x=25.408768, y=13.125496, z=0.000000)
# Noisy Waypoint Applied: Location(x=21.431070, y=12.102761, z=0.000000)
# Noisy Waypoint Applied: Location(x=19.156521, y=12.387406, z=0.000000)
# Noisy Waypoint Applied: Location(x=14.731826, y=14.312451, z=0.000000)
# Noisy Waypoint Applied: Location(x=11.416707, y=14.115754, z=0.000000)
# Noisy Waypoint Applied: Location(x=6.587602, y=14.701159, z=0.000000)
# Noisy Waypoint Applied: Location(x=4.008464, y=13.035275, z=0.000000)
# Noise level increased to 1.8 meters
# Noisy Waypoint Applied: Location(x=-1.171784, y=13.069296, z=0.000000)
# Noisy Waypoint Applied: Location(x=-3.154006, y=12.124204, z=0.000000)
# Noisy Waypoint Applied: Location(x=-6.457622, y=11.450964, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-47.627995, y=-39.814686, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.904190, y=-34.816055, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.559620, y=-29.168264, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-81.972092, y=25.629431, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=108.123199, y=-25.472443, z=0.000000)
# Noisy Waypoint Applied: Location(x=108.023476, y=-30.094110, z=0.000000)
# Noisy Waypoint Applied: Location(x=109.198677, y=-35.424496, z=0.000000)
# Noisy Waypoint Applied: Location(x=107.469963, y=-40.519543, z=0.000000)
# ...
# Noisy Waypoint Applied: Location(x=106.848236, y=75.192497, z=0.000000)
# Noisy Waypoint Applied: Location(x=107.602493, y=69.947334, z=0.000000)
# Noisy Waypoint Applied: Location(x=108.033730, y=63.947586, z=0.000000)
# Noisy Waypoint Applied: Location(x=111.469299, y=60.486824, z=0.000000)
# Noisy Waypoint Applied: Location(x=108.677231, y=57.779533, z=0.000000)
# Noisy Waypoint Applied: Location(x=108.364792, y=51.041725, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-50.096748, y=-35.405361, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.244347, y=-31.020594, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.975239, y=-26.821791, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.330517, y=-31.960825, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=97.175835, y=-13.837590, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=49.734585, y=-67.926208, z=0.000000)
# Noisy Waypoint Applied: Location(x=41.081654, y=-67.303268, z=0.000000)
# Noisy Waypoint Applied: Location(x=32.953232, y=-68.032814, z=0.000000)
# Noisy Waypoint Applied: Location(x=27.255594, y=-70.001396, z=0.000000)
# Noisy Waypoint Applied: Location(x=18.553205, y=-68.898865, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=4.168367, y=-63.729244, z=0.000000)
# Noisy Waypoint Applied: Location(x=-3.474095, y=-66.428482, z=0.000000)
# Noisy Waypoint Applied: Location(x=-11.749841, y=-70.360313, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=51.163784, y=130.547913, z=0.000000)
# Noisy Waypoint Applied: Location(x=41.972260, y=130.708908, z=0.000000)
# Noisy Waypoint Applied: Location(x=35.176113, y=130.635178, z=0.000000)
# Noisy Waypoint Applied: Location(x=26.562420, y=129.412048, z=0.000000)
# Noisy Waypoint Applied: Location(x=18.391720, y=129.759857, z=0.000000)
# Noisy Waypoint Applied: Location(x=10.098907, y=128.450989, z=0.000000)
# Noisy Waypoint Applied: Location(x=4.356573, y=130.731247, z=0.000000)
# Noisy Waypoint Applied: Location(x=-4.970755, y=129.280563, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=92.734352, y=12.429270, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-4.945861, y=139.478683, z=0.000000)
# Noisy Waypoint Applied: Location(x=-1.345603, y=141.355148, z=0.000000)
# Noisy Waypoint Applied: Location(x=6.277630, y=140.646606, z=0.000000)
# Noisy Waypoint Applied: Location(x=13.548013, y=141.411453, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-91.896896, y=12.952189, z=0.000000)
# Noisy Waypoint Applied: Location(x=-98.365547, y=11.509968, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.574669, y=12.149906, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.351974, y=5.735444, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.965599, y=3.661287, z=0.000000)
# Noisy Waypoint Applied: Location(x=-106.805237, y=1.587141, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.800018, y=-2.812054, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.183090, y=-5.324775, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.596504, y=-11.390504, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.899078, y=-14.016406, z=0.000000)
# Noisy Waypoint Applied: Location(x=-103.310806, y=-16.182184, z=0.000000)
# Noisy Waypoint Applied: Location(x=-104.929680, y=-20.935295, z=0.000000)
# Noisy Waypoint Applied: Location(x=-107.981003, y=-27.657093, z=0.000000)
# Noisy Waypoint Applied: Location(x=-112.344635, y=-20.060425, z=0.000000)
# Noisy Waypoint Applied: Location(x=-115.504868, y=-13.906133, z=0.000000)
# Noisy Waypoint Applied: Location(x=-116.223297, y=-9.163082, z=0.000000)
# Noisy Waypoint Applied: Location(x=-111.548790, y=-5.476272, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noise level increased to 2.9999999999999996 meters
# Noisy Waypoint Applied: Location(x=56.808887, y=14.443069, z=0.000000)
# Noisy Waypoint Applied: Location(x=48.449203, y=11.181194, z=0.000000)
# Noisy Waypoint Applied: Location(x=37.606609, y=13.949071, z=0.000000)
# Noisy Waypoint Applied: Location(x=29.850660, y=11.484674, z=0.000000)
# Noisy Waypoint Applied: Location(x=19.367332, y=14.507899, z=0.000000)
# Noisy Waypoint Applied: Location(x=10.965669, y=11.311089, z=0.000000)
# Noisy Waypoint Applied: Location(x=0.257446, y=16.149389, z=0.000000)
# Noisy Waypoint Applied: Location(x=-11.826294, y=17.068876, z=0.000000)
# Noisy Waypoint Applied: Location(x=-23.000500, y=15.988654, z=0.000000)
# Noisy Waypoint Applied: Location(x=-33.850422, y=15.627555, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.643131, y=15.977088, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.780357, y=19.322601, z=0.000000)
# Noisy Waypoint Applied: Location(x=-65.630524, y=19.305431, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-24.696377, y=-65.575325, z=0.000000)
# Noisy Waypoint Applied: Location(x=-33.756081, y=-63.213089, z=0.000000)
# Noisy Waypoint Applied: Location(x=-41.142162, y=-63.751755, z=0.000000)
# Noisy Waypoint Applied: Location(x=-42.757690, y=-58.413410, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.412537, y=-60.588676, z=0.000000)
# Noisy Waypoint Applied: Location(x=-36.698395, y=-63.123878, z=0.000000)
# Noisy Waypoint Applied: Location(x=-41.082870, y=-61.496586, z=0.000000)
# Noisy Waypoint Applied: Location(x=-36.151764, y=-59.771481, z=0.000000)
# Noisy Waypoint Applied: Location(x=-32.287315, y=-63.082355, z=0.000000)
# Noisy Waypoint Applied: Location(x=-28.977293, y=-61.212795, z=0.000000)
# Noisy Waypoint Applied: Location(x=-24.271761, y=-63.951973, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=8.052537, y=26.108770, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-112.037598, y=67.319176, z=0.000000)
# Noisy Waypoint Applied: Location(x=-111.775856, y=81.739769, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.952698, y=93.835503, z=0.000000)
# Noisy Waypoint Applied: Location(x=-102.172028, y=97.356827, z=0.000000)
# Noisy Waypoint Applied: Location(x=-101.850037, y=103.171997, z=0.000000)
# Noisy Waypoint Applied: Location(x=-102.141220, y=106.575798, z=0.000000)
# Noisy Waypoint Applied: Location(x=-97.527321, y=110.266785, z=0.000000)
# Noisy Waypoint Applied: Location(x=-96.148590, y=116.281418, z=0.000000)
# Noisy Waypoint Applied: Location(x=-89.307671, y=125.975677, z=0.000000)
# Noisy Waypoint Applied: Location(x=-77.821068, y=134.100067, z=0.000000)
# Noisy Waypoint Applied: Location(x=-65.195175, y=136.103989, z=0.000000)
# Noisy Waypoint Applied: Location(x=-55.056427, y=135.767212, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.947411, y=138.737900, z=0.000000)
# Noisy Waypoint Applied: Location(x=-29.290737, y=141.863388, z=0.000000)
# Noisy Waypoint Applied: Location(x=-19.760946, y=139.143799, z=0.000000)
# Noisy Waypoint Applied: Location(x=-5.211242, y=139.856247, z=0.000000)
# Noisy Waypoint Applied: Location(x=4.247300, y=138.897827, z=0.000000)
# Noisy Waypoint Applied: Location(x=16.209173, y=138.899902, z=0.000000)
# Noisy Waypoint Applied: Location(x=29.103653, y=138.579117, z=0.000000)
# Noisy Waypoint Applied: Location(x=39.469627, y=136.454391, z=0.000000)
# Noisy Waypoint Applied: Location(x=52.891525, y=135.194794, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=24.522362, y=19.138023, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=55.032719, y=67.363716, z=0.000000)
# Noisy Waypoint Applied: Location(x=49.433701, y=69.159943, z=0.000000)
# Noisy Waypoint Applied: Location(x=53.336975, y=69.395699, z=0.000000)
# Noisy Waypoint Applied: Location(x=59.164822, y=69.496315, z=0.000000)
# Noisy Waypoint Applied: Location(x=65.863953, y=69.235672, z=0.000000)
# Noisy Waypoint Applied: Location(x=72.766678, y=69.316505, z=0.000000)
# Noisy Waypoint Applied: Location(x=77.785461, y=68.080383, z=0.000000)
# Noisy Waypoint Applied: Location(x=72.845650, y=67.998299, z=0.000000)
# Noisy Waypoint Applied: Location(x=64.826164, y=63.814365, z=0.000000)
# Noisy Waypoint Applied: Location(x=61.922531, y=65.588547, z=0.000000)
# Noisy Waypoint Applied: Location(x=55.506027, y=65.101486, z=0.000000)
# Noisy Waypoint Applied: Location(x=51.563961, y=67.538078, z=0.000000)
# Noisy Waypoint Applied: Location(x=48.298809, y=68.328247, z=0.000000)
# Noisy Waypoint Applied: Location(x=53.224144, y=70.234665, z=0.000000)
# Noisy Waypoint Applied: Location(x=58.192524, y=68.223923, z=0.000000)
# Noisy Waypoint Applied: Location(x=63.816875, y=68.527405, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=49.724487, y=-67.069412, z=0.000000)
# Noisy Waypoint Applied: Location(x=43.450420, y=-67.878716, z=0.000000)
# Noisy Waypoint Applied: Location(x=37.554848, y=-67.904953, z=0.000000)
# Noisy Waypoint Applied: Location(x=33.210457, y=-65.409637, z=0.000000)
# Noisy Waypoint Applied: Location(x=24.601093, y=-66.285454, z=0.000000)
# Noisy Waypoint Applied: Location(x=17.147943, y=-68.858521, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-49.767277, y=-11.119135, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.636612, y=-14.360703, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.821911, y=-14.590612, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.503391, y=-12.351034, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.398186, y=-11.430352, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.543808, y=-14.432792, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.955280, y=-12.111897, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.117687, y=-10.528807, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.692924, y=-11.463190, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.845100, y=-15.931096, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.950108, y=-13.390651, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.416206, y=-10.606120, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.822891, y=-15.080125, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.122318, y=-15.769372, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.667850, y=-11.196903, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.325935, y=-15.721584, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.343872, y=-15.676841, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.726948, y=-10.879095, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.379414, y=-14.546621, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.730572, y=-14.779158, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.729576, y=-13.590629, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.698994, y=-15.553306, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.306255, y=-12.396870, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.655487, y=-12.751872, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.036610, y=-13.011503, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.728779, y=-13.805309, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.194595, y=-11.297268, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.479504, y=-11.480058, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.137917, y=-10.644345, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.899513, y=-12.246248, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.926266, y=-14.710242, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.385006, y=-14.643818, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.892738, y=-10.857040, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.766731, y=-14.893449, z=0.000000)
# Noisy Waypoint Applied: Location(x=-51.483635, y=-10.742036, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.788033, y=-12.567793, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.416733, y=-15.523614, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.937435, y=-12.934626, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.443012, y=-11.903635, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.654339, y=-15.237817, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.039635, y=-12.323426, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.477581, y=-11.427979, z=0.000000)
# Noisy Waypoint Applied: Location(x=-48.067616, y=-11.232444, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.974098, y=-11.707120, z=0.000000)
# Cleaning up...
# Incident data saved to waypoint_noise_incidents.csv
# Total crashes recorded: 155
# Vehicle & sensors destroyed. Exiting program.

# %%
df = pd.DataFrame(data_records)
df.to_csv("waypoint_noise_incidents.csv", index=False)
print(f"Incident data saved to waypoint_noise_incidents.csv")

plt.figure(figsize=(8, 5))
df_crash = df[df["Collision"] == "Yes"]
plt.scatter(df_crash["Noise_Level"], df_crash.index, color='red', label='Collisions')
plt.xlabel("Noise Level (meters)")
plt.ylabel("Collision Occurrence")
plt.title("Impact of Noise on Collisions")
plt.legend()
plt.grid()
plt.show()
# Out:
# Incident data saved to waypoint_noise_incidents.csv
