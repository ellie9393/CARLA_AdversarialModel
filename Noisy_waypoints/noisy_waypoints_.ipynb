# %%
import carla
import time
import datetime
import random
import pandas as pd

# Connect to CARLA
client = carla.Client('localhost', 2000)
client.set_timeout(5.0)
world = client.get_world()

# Get map and spawn points
map = world.get_map()
spawn_points = map.get_spawn_points()
start_point = random.choice(spawn_points)

# Spawn the vehicle
vehicle_bp = world.get_blueprint_library().filter('*firetruck*')[0]
vehicle = world.try_spawn_actor(vehicle_bp, start_point)

if not vehicle:
    print("Failed to spawn vehicle.")
    exit()

print(f"Vehicle spawned at {start_point.location}")

# Disable autopilot (We will manually apply noisy waypoints)
vehicle.set_autopilot(False)

# Attach Collision Sensor
collision_bp = world.get_blueprint_library().find('sensor.other.collision')
collision_sensor = world.spawn_actor(collision_bp, carla.Transform(), attach_to=vehicle)

# Set up Excel File for Results
excel_filename = "waypoint_noise_incidents.csv"

# Create a list to store results (faster than DataFrame updates)
data_records = []

# Waypoint Noise Model (More Intense Noise)
def noisy_waypoint(original_waypoint, noise_level=1.5):  # Noise in meters
    noisy_x = original_waypoint.transform.location.x + random.uniform(-noise_level, noise_level)
    noisy_y = original_waypoint.transform.location.y + random.uniform(-noise_level, noise_level)
    noisy_z = original_waypoint.transform.location.z  # Keeping altitude the same
    return carla.Transform(carla.Location(x=noisy_x, y=noisy_y, z=noisy_z), original_waypoint.transform.rotation)

# Track simulation time
start_time = time.time()
crash_count = 0  # Track number of crashes

# Collision detection function (Reset position instead of stopping)
def collision_callback(event):
    global crash_count
    print("Collision detected!")

    crash_count += 1  # Increment crash count

    # Log collision event
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    data_records.append({
        "Timestamp": timestamp,
        "Waypoint_X": None,  # No waypoint update here
        "Waypoint_Y": None,
        "Waypoint_Z": None,
        "Noisy_Waypoint_X": None,
        "Noisy_Waypoint_Y": None,
        "Noisy_Waypoint_Z": None,
        "Collision": "Yes",
        "Collision_Object": str(event.other_actor)
    })

    # Reset vehicle to a new random spawn point
    reset_location = random.choice(spawn_points)
    vehicle.set_transform(reset_location)

    print("Vehicle reset after collision. Continuing experiment.")

# Cleanup function
def cleanup():
    print("Cleaning up...")

    # Convert collected data into a DataFrame and save to Excel
    df = pd.DataFrame(data_records)
    df.to_csv(excel_filename, index=False)
    print(f"Incident data saved to {excel_filename}")
    
    print(f"Total crashes recorded: {crash_count}")

    if collision_sensor:
        collision_sensor.destroy()
    if vehicle:
        vehicle.destroy()
    print("Vehicle & sensors destroyed. Exiting program.")

# Start collision sensor
collision_sensor.listen(collision_callback)

# Move vehicle along waypoints with noise
print("Vehicle navigating with noisy waypoints...")

try:
    while True:
        current_location = vehicle.get_location()
        next_waypoint_options = map.get_waypoint(current_location).next(5.0)

        if not next_waypoint_options:
            print("No further waypoints found! Resetting vehicle...")
            vehicle.set_transform(random.choice(spawn_points))
            continue
        
        next_waypoint = next_waypoint_options[0]  # Get next waypoint 5 meters ahead

        # Apply noise to waypoint
        noisy_transform = noisy_waypoint(next_waypoint, noise_level=2.0)  # 2m max deviation
        vehicle.set_transform(noisy_transform)  # Move vehicle to noisy waypoint

        # Log waypoint data
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data_records.append({
            "Timestamp": timestamp,
            "Waypoint_X": next_waypoint.transform.location.x,
            "Waypoint_Y": next_waypoint.transform.location.y,
            "Waypoint_Z": next_waypoint.transform.location.z,
            "Noisy_Waypoint_X": noisy_transform.location.x,
            "Noisy_Waypoint_Y": noisy_transform.location.y,
            "Noisy_Waypoint_Z": noisy_transform.location.z,
            "Collision": "No",
            "Collision_Object": "None"
        })

        print(f"Noisy Waypoint Applied: {noisy_transform.location}")

        time.sleep(0.5)  # Pause between movements

        # Stop after 1 minute
        if time.time() - start_time >= 60:
            print("Time limit reached (1 minute). Stopping simulation...")
            cleanup()
            break

except KeyboardInterrupt:
    print("\n Manual stop detected! Cleaning up before exiting...")
    cleanup()
# Out:
# Vehicle spawned at Location(x=-87.276062, y=24.441530, z=0.600000)
# Vehicle navigating with noisy waypoints...
# Noisy Waypoint Applied: Location(x=-81.884201, y=24.430681, z=0.000000)
# Noisy Waypoint Applied: Location(x=-78.784851, y=25.895439, z=0.000000)
# Noisy Waypoint Applied: Location(x=-74.501480, y=25.483891, z=0.000000)
# Noisy Waypoint Applied: Location(x=-69.724052, y=22.758841, z=0.000000)
# Noisy Waypoint Applied: Location(x=-64.200676, y=26.070770, z=0.000000)
# Noisy Waypoint Applied: Location(x=-60.722179, y=24.773033, z=0.000000)
# Noisy Waypoint Applied: Location(x=-53.902931, y=23.307392, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.082016, y=21.382908, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.164764, y=15.195541, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.452858, y=11.473553, z=0.000000)
# Noisy Waypoint Applied: Location(x=-42.357857, y=6.829722, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.593555, y=2.724502, z=0.000000)
# Noisy Waypoint Applied: Location(x=-43.340885, y=-1.762528, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.853664, y=-5.023908, z=0.000000)
# Noisy Waypoint Applied: Location(x=-42.450329, y=-9.403341, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.201653, y=-12.898887, z=0.000000)
# Noisy Waypoint Applied: Location(x=-43.275082, y=-18.164667, z=0.000000)
# Noisy Waypoint Applied: Location(x=-41.238983, y=-22.832136, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.146805, y=-27.291752, z=0.000000)
# Noisy Waypoint Applied: Location(x=-42.552570, y=-32.228683, z=0.000000)
# Noisy Waypoint Applied: Location(x=-41.376419, y=-36.978348, z=0.000000)
# Noisy Waypoint Applied: Location(x=-41.045338, y=-40.471279, z=0.000000)
# Noisy Waypoint Applied: Location(x=-42.565300, y=-45.247120, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.500526, y=-48.985950, z=0.000000)
# Noisy Waypoint Applied: Location(x=-39.017017, y=-52.296989, z=0.000000)
# Noisy Waypoint Applied: Location(x=-37.647659, y=-56.689957, z=0.000000)
# Noisy Waypoint Applied: Location(x=-33.936680, y=-58.939892, z=0.000000)
# Noisy Waypoint Applied: Location(x=-31.327745, y=-60.256893, z=0.000000)
# Noisy Waypoint Applied: Location(x=-27.122252, y=-61.728687, z=0.000000)
# Noisy Waypoint Applied: Location(x=-23.055984, y=-62.839249, z=0.000000)
# Noisy Waypoint Applied: Location(x=-18.973146, y=-60.062771, z=0.000000)
# Noisy Waypoint Applied: Location(x=-15.100101, y=-62.040035, z=0.000000)
# Noisy Waypoint Applied: Location(x=-8.294643, y=-63.063305, z=0.000000)
# Noisy Waypoint Applied: Location(x=-14.654016, y=-64.628563, z=0.000000)
# Noisy Waypoint Applied: Location(x=-18.441582, y=-64.752182, z=0.000000)
# Noisy Waypoint Applied: Location(x=-23.546696, y=-65.511360, z=0.000000)
# Noisy Waypoint Applied: Location(x=-29.711889, y=-65.444740, z=0.000000)
# Noisy Waypoint Applied: Location(x=-33.802490, y=-64.022392, z=0.000000)
# Noisy Waypoint Applied: Location(x=-37.601017, y=-65.502571, z=0.000000)
# Noisy Waypoint Applied: Location(x=-43.266895, y=-63.748852, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.003155, y=-64.331604, z=0.000000)
# Noisy Waypoint Applied: Location(x=-53.584026, y=-66.502632, z=0.000000)
# Noisy Waypoint Applied: Location(x=-59.947235, y=-67.784164, z=0.000000)
# Noisy Waypoint Applied: Location(x=-64.616798, y=-68.041229, z=0.000000)
# Noisy Waypoint Applied: Location(x=-70.329185, y=-68.153297, z=0.000000)
# Noisy Waypoint Applied: Location(x=-76.559937, y=-67.265785, z=0.000000)
# Noisy Waypoint Applied: Location(x=-83.160362, y=-68.366173, z=0.000000)
# Noisy Waypoint Applied: Location(x=-86.336868, y=-64.834824, z=0.000000)
# Noisy Waypoint Applied: Location(x=-91.387268, y=-63.744186, z=0.000000)
# Noisy Waypoint Applied: Location(x=-93.996696, y=-58.557953, z=0.000000)
# Noisy Waypoint Applied: Location(x=-96.855988, y=-54.354645, z=0.000000)
# Noisy Waypoint Applied: Location(x=-102.044182, y=-51.540367, z=0.000000)
# Noisy Waypoint Applied: Location(x=-105.573425, y=-45.939426, z=0.000000)
# Noisy Waypoint Applied: Location(x=-109.921135, y=-40.968819, z=0.000000)
# Noisy Waypoint Applied: Location(x=-111.195549, y=-36.427326, z=0.000000)
# Noisy Waypoint Applied: Location(x=-112.396225, y=-32.551128, z=0.000000)
# Noisy Waypoint Applied: Location(x=-113.802605, y=-27.596762, z=0.000000)
# Noisy Waypoint Applied: Location(x=-113.878517, y=-23.303919, z=0.000000)
# Noisy Waypoint Applied: Location(x=-114.464622, y=-17.823107, z=0.000000)
# Noisy Waypoint Applied: Location(x=-113.760887, y=-10.899946, z=0.000000)
# Noisy Waypoint Applied: Location(x=-112.225357, y=-4.538229, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=24.947025, y=-65.142372, z=0.000000)
# Noisy Waypoint Applied: Location(x=20.404022, y=-63.442722, z=0.000000)
# Noisy Waypoint Applied: Location(x=14.186953, y=-65.470505, z=0.000000)
# Noisy Waypoint Applied: Location(x=10.306778, y=-65.601486, z=0.000000)
# Noisy Waypoint Applied: Location(x=6.844582, y=-63.981033, z=0.000000)
# Noisy Waypoint Applied: Location(x=1.459055, y=-63.535408, z=0.000000)
# Noisy Waypoint Applied: Location(x=-4.601190, y=-64.949593, z=0.000000)
# Noisy Waypoint Applied: Location(x=-8.626795, y=-66.051926, z=0.000000)
# Noisy Waypoint Applied: Location(x=-13.309814, y=-65.169022, z=0.000000)
# Noisy Waypoint Applied: Location(x=-19.734093, y=-63.731396, z=0.000000)
# Noisy Waypoint Applied: Location(x=-25.263592, y=-63.432278, z=0.000000)
# Noisy Waypoint Applied: Location(x=-29.006208, y=-66.768211, z=0.000000)
# Noisy Waypoint Applied: Location(x=-32.573986, y=-66.703110, z=0.000000)
# Noisy Waypoint Applied: Location(x=-36.091419, y=-67.313576, z=0.000000)
# Noisy Waypoint Applied: Location(x=-40.825283, y=-70.229912, z=0.000000)
# Noisy Waypoint Applied: Location(x=-44.455818, y=-70.193634, z=0.000000)
# Noisy Waypoint Applied: Location(x=-47.510601, y=-68.103195, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.763969, y=-68.635445, z=0.000000)
# Noisy Waypoint Applied: Location(x=-56.487736, y=-69.358131, z=0.000000)
# Noisy Waypoint Applied: Location(x=-59.759766, y=-67.950333, z=0.000000)
# Noisy Waypoint Applied: Location(x=-66.436066, y=-69.178200, z=0.000000)
# Noisy Waypoint Applied: Location(x=-73.534821, y=-68.636604, z=0.000000)
# Noisy Waypoint Applied: Location(x=-78.205528, y=-66.534927, z=0.000000)
# Noisy Waypoint Applied: Location(x=-84.942223, y=-67.621925, z=0.000000)
# Noisy Waypoint Applied: Location(x=-89.107529, y=-62.508259, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=51.060757, y=-55.683826, z=0.000000)
# Noisy Waypoint Applied: Location(x=54.880524, y=-58.495628, z=0.000000)
# Noisy Waypoint Applied: Location(x=59.634609, y=-55.654076, z=0.000000)
# Noisy Waypoint Applied: Location(x=64.732300, y=-56.349083, z=0.000000)
# Noisy Waypoint Applied: Location(x=69.052666, y=-57.047115, z=0.000000)
# Noisy Waypoint Applied: Location(x=74.133743, y=-54.967674, z=0.000000)
# Noisy Waypoint Applied: Location(x=77.469131, y=-54.150288, z=0.000000)
# Noisy Waypoint Applied: Location(x=81.049431, y=-53.965836, z=0.000000)
# Noisy Waypoint Applied: Location(x=86.248810, y=-51.854328, z=0.000000)
# Noisy Waypoint Applied: Location(x=88.584099, y=-46.356308, z=0.000000)
# Noisy Waypoint Applied: Location(x=94.199028, y=-44.886219, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.025391, y=-42.387047, z=0.000000)
# Noisy Waypoint Applied: Location(x=99.630722, y=-36.113037, z=0.000000)
# Noisy Waypoint Applied: Location(x=103.377731, y=-30.230883, z=0.000000)
# Noisy Waypoint Applied: Location(x=101.190254, y=-26.430099, z=0.000000)
# Noisy Waypoint Applied: Location(x=103.984558, y=-19.785002, z=0.000000)
# Noisy Waypoint Applied: Location(x=102.123741, y=-13.701840, z=0.000000)
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Collision detected!
# Vehicle reset after collision. Continuing experiment.
# Noisy Waypoint Applied: Location(x=-53.745514, y=3.765726, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.723877, y=7.415010, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.209026, y=11.839287, z=0.000000)
# Noisy Waypoint Applied: Location(x=-52.526546, y=17.099094, z=0.000000)
# Noisy Waypoint Applied: Location(x=-50.715977, y=23.999990, z=0.000000)
# Noisy Waypoint Applied: Location(x=-45.123909, y=24.028555, z=0.000000)
# Noisy Waypoint Applied: Location(x=-46.370468, y=30.009441, z=0.000000)
# Noisy Waypoint Applied: Location(x=-49.006474, y=25.466997, z=0.000000)
# Noisy Waypoint Applied: Location(x=-53.977360, y=20.525612, z=0.000000)
# Noisy Waypoint Applied: Location(x=-58.365841, y=17.709251, z=0.000000)
# Noisy Waypoint Applied: Location(x=-62.667419, y=17.898039, z=0.000000)
# Noisy Waypoint Applied: Location(x=-67.366478, y=17.401291, z=0.000000)
# Noisy Waypoint Applied: Location(x=-72.438393, y=15.744803, z=0.000000)
# Noisy Waypoint Applied: Location(x=-76.404266, y=18.012136, z=0.000000)
# Noisy Waypoint Applied: Location(x=-83.288612, y=17.617268, z=0.000000)
# Noisy Waypoint Applied: Location(x=-87.091957, y=18.115561, z=0.000000)
# Time limit reached (1 minute). Stopping simulation...
# Cleaning up...
# Incident data saved to waypoint_noise_incidents.csv
# Total crashes recorded: 4
# Vehicle & sensors destroyed. Exiting program.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
excel_filename = "waypoint_noise_incidents.csv"
df = pd.read_csv(excel_filename)

# Print basic statistics
total_waypoints = len(df[df["Collision"] == "No"])
total_crashes = len(df[df["Collision"] == "Yes"])

print(f"Total waypoints visited: {total_waypoints}")
print(f"Total crashes recorded: {total_crashes}")
# Out:
# Total waypoints visited: 119
# Total crashes recorded: 4
